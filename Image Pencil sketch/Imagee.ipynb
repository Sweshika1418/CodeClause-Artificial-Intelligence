# %% [markdown]
# This program coverts an image into a pencil sketch using Python

# %%
#import the library
import cv2

# %%
#get the image location and the image file name
Image_Location = '/content/Retriver.jpg'
filename = 'Retriver.jpg'

# %%
#Reading the image
image = cv2.imread(Image_Location+filename)

# %%
from google.colab.patches import cv2_imshow

'''cv2.imshow('Original Image',image)
cv2.waitKey(0)   #'C:/Users/hp/Desktop/Lets Grow More/' '''

img = cv2.imread('/content/Retriver.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x739>

# %%
#Converting the image into gray
Gray_Image = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#Here the BGR means blue green red converts to gray color

# %%
#Inverting the image
inverted_gray_image = 255 - Gray_Image

# %%
#Blurring the image by gaussian function
blurred_image = cv2.GaussianBlur(inverted_gray_image,(21,21),0)

# %%
#Inverting the blurred image
inverted_blurred_image = 255 - blurred_image

# %%
#create the pencil sketch image
Pencil_Sketch_IMG = cv2.divide(Gray_Image, inverted_blurred_image, scale=256.0)

# %%
#Showing the image

cv2_imshow(img)

cv2_imshow(Pencil_Sketch_IMG)

cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=600x739>
# <PIL.Image.Image image mode=L size=600x739>
# -1
